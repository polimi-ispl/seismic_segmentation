# %% [markdown]
# # 2020 SEG Annual Meeting Machine Learning Interpretation Workshop

# %%
import os  
import numpy as np
from time import time

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

import tensorflow.keras.backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import architecture as a
import data as d
from PatchExtractor import PatchExtractor as PE
from utils import normalize_only, normalize

seed = 0
np.random.seed(seed)

#Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Plotting library
from matplotlib import pyplot as plt
from matplotlib import rcParams
from plotting import plot_label
from mpl_toolkits.axes_grid1 import make_axes_locatable

rcParams.update({
    'image.cmap'     : 'gray',
    'axes.grid'      : False,
    'savefig.dpi'    : 300,  # to adjust notebook inline plot size
    'axes.labelsize' : 14,  # fontsize for x and y labels (was 10)
    'axes.titlesize' : 14,
    'font.size'      : 14,
    'legend.fontsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'text.usetex'    : True
})

# %%
CLASS_NAMES = ["Basement", "SlopeMudA", "Deposit", "SlopeMudB", "SlopeValley", "Canyon"]
num_classes = len(CLASS_NAMES)
dataset = "/nas/public/dataset/geophysics/BlindTestSEG/"
num_sections = 256

# %%
image = np.load(os.path.join(dataset, "train_image.npy"))[:,:num_sections,:]
label = np.load(os.path.join(dataset, "train_labels.npy"))[:,:num_sections,:].astype(np.uint8)-1

# %%
print('x\ty\tz')
print('%d\t%d\t%d' % (image.shape[0],image.shape[1],image.shape[2]))
# Out:
# x	y	z
# 590	256	1006

# %%
plt.hist(label.ravel(), 6)
plt.xticks(np.linspace(0.5,4.5,num_classes), CLASS_NAMES, rotation=90)
plt.show()

# %% [markdown]
# Classes are quite unbalanced! There's little or no class 4

# %% [markdown]
# ## Data Loaders

# %%
pe = PE(dim=(992,128), stride=(2,32))

# %%
patches_img = []
patches_msk = []
for inline in range(image.shape[1]):
    patches_img.append(pe.extract(image[:,inline].T))
    patches_msk.append(pe.extract(label[:,inline].T))
    
patches_img = np.asarray(patches_img).reshape((-1,)+pe.dim+(1,))
patches_msk = np.asarray(patches_msk).reshape((-1,)+pe.dim+(1,))

# %%
in_min = patches_img.min()
in_max = patches_img.max()
normalization = lambda x: normalize_only(x, in_min=in_min, in_max=in_max, zero_mean=True)

# %%
bound = patches_img.shape[0]//2

# %%
train_gen = d.PatchArrayLoader(batch_size=32,
                               input_array=patches_img[:bound],
                               target_array=patches_msk[:bound],
                               input_transform=normalization,
                               target_transform=to_categorical)

val_gen = d.PatchArrayLoader(batch_size=32,
                       input_array=patches_img[bound:],
                       target_array=patches_msk[bound:],
                       input_transform=normalization,
                       target_transform=to_categorical)

# %% [markdown]
# #### Model

# %%
# Build model
K.clear_session()
model = a.Xception(pe.dim+(1,), num_classes=num_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 992, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 496, 64, 32)  320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 496, 64, 32)  128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 496, 64, 32)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 496, 64, 32)  0           activation[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 496, 64, 64)  2400        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 496, 64, 64)  256         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 496, 64, 64)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 496, 64, 64)  4736        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 496, 64, 64)  256         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 248, 32, 64)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 248, 32, 64)  2112        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 248, 32, 64)  0           max_pooling2d[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 248, 32, 64)  0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 248, 32, 128) 8896        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 248, 32, 128) 512         separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 248, 32, 128) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 248, 32, 128) 17664       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 248, 32, 128) 512         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 124, 16, 128) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 124, 16, 128) 8320        add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 124, 16, 128) 0           max_pooling2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 124, 16, 128) 0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 124, 16, 256) 34176       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 124, 16, 256) 1024        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 124, 16, 256) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 124, 16, 256) 68096       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 124, 16, 256) 1024        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 62, 8, 256)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 62, 8, 256)   33024       add_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 62, 8, 256)   0           max_pooling2d_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 62, 8, 256)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 62, 8, 256)   590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 62, 8, 256)   1024        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 62, 8, 256)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 62, 8, 256)   590080      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 62, 8, 256)   1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 124, 16, 256) 0           add_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 124, 16, 256) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 124, 16, 256) 65792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 124, 16, 256) 0           up_sampling2d[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 124, 16, 256) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 124, 16, 128) 295040      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 124, 16, 128) 512         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 124, 16, 128) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 124, 16, 128) 147584      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 124, 16, 128) 512         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 248, 32, 256) 0           add_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 248, 32, 128) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 248, 32, 128) 32896       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 248, 32, 128) 0           up_sampling2d_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 248, 32, 128) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 248, 32, 64)  73792       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 248, 32, 64)  256         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 248, 32, 64)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 248, 32, 64)  36928       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 248, 32, 64)  256         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 496, 64, 128) 0           add_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 496, 64, 64)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 496, 64, 64)  8256        up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 496, 64, 64)  0           up_sampling2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 496, 64, 64)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 496, 64, 32)  18464       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 496, 64, 32)  128         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 496, 64, 32)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 496, 64, 32)  9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 496, 64, 32)  128         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 992, 128, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 992, 128, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 992, 128, 32) 2080        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 992, 128, 32) 0           up_sampling2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 992, 128, 6)  1734        add_6[0][0]
# ==================================================================================================
# Total params: 2,059,270
# Trainable params: 2,055,494
# Non-trainable params: 3,776
# __________________________________________________________________________________________________

# %%
model.compile(optimizer="rmsprop", loss='bce')

# %%
callbacks = [
    ModelCheckpoint("test3_weights.h5", save_best_only=True),
    # EarlyStopping(patience=5),
]

# %%
history = model.fit(train_gen, validation_data=val_gen,
                    epochs=10, callbacks=callbacks, verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 480 steps, validate for 480 steps
# Epoch 1/10
# 480/480 [==============================] - 467s 972ms/step - loss: 0.1032 - val_loss: 2.4866
# Epoch 2/10
# 480/480 [==============================] - 457s 951ms/step - loss: 0.0269 - val_loss: 0.0680
# Epoch 3/10
# 480/480 [==============================] - 456s 951ms/step - loss: 0.0180 - val_loss: 0.0704
# Epoch 4/10
# 480/480 [==============================] - 455s 947ms/step - loss: 0.0149 - val_loss: 0.0776
# Epoch 5/10
# 480/480 [==============================] - 446s 930ms/step - loss: 0.0130 - val_loss: 0.0821
# Epoch 6/10
# 480/480 [==============================] - 450s 938ms/step - loss: 0.0124 - val_loss: 0.0862
# Epoch 7/10
# 480/480 [==============================] - 449s 935ms/step - loss: 0.0113 - val_loss: 0.0759
# Epoch 8/10
# 480/480 [==============================] - 449s 935ms/step - loss: 0.0101 - val_loss: 0.0796
# Epoch 9/10
# 480/480 [==============================] - 449s 935ms/step - loss: 0.0099 - val_loss: 0.1116
# Epoch 10/10
# 480/480 [==============================] - 451s 940ms/step - loss: 0.0087 - val_loss: 0.0798

# %%
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], label='Training')
plt.plot(history.history['val_loss'], label='Validation')
plt.xlim(0,10)
plt.ylim(0)
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Visualize

# %%
img, msk = train_gen[0][0][0], train_gen[0][1][0]
out = model.predict(img[np.newaxis]).squeeze()

# %%
fig, axs = plt.subplots(1, 3, sharey=True, figsize=(12, 12))

data=axs[0].imshow(img.squeeze())
axs[0].set_title('Data')

plot_label(np.argmax(msk, axis=-1),
           fig, axs[1], num_classes, labels=CLASS_NAMES)
axs[1].set_title('Label')

plot_label(np.argmax(out, axis=-1).squeeze(),
           fig, axs[2], num_classes, labels=CLASS_NAMES)
axs[2].set_title('Output')

plt.show()

# %%
img, msk = val_gen[0][0][0], val_gen[0][1][0]
out = model.predict(img[np.newaxis]).squeeze()

# %%
fig, axs = plt.subplots(1, 3, sharey=True, figsize=(12, 12))

data=axs[0].imshow(img.squeeze())
axs[0].set_title('Data')

plot_label(np.argmax(msk, axis=-1),
           fig, axs[1], num_classes, labels=CLASS_NAMES)
axs[1].set_title('Label')

plot_label(np.argmax(out, axis=-1).squeeze(),
           fig, axs[2], num_classes, labels=CLASS_NAMES)
axs[2].set_title('Output')

plt.show()

# %% [markdown]
# ## Test

# %%
test_image = np.load(os.path.join(dataset, "train_image.npy"))[:,-1,:]
test_label = np.load(os.path.join(dataset, "train_labels.npy"))[:,-1,:].astype(np.uint8)-1

# %%
patch_img = pe.extract(test_image.T).reshape((-1,)+pe.dim+(1,))
patch_msk = pe.extract(test_label.T).reshape((-1,)+pe.dim+(1,))

# %%
patch_out = model.predict(normalize(patch_img, in_min, in_max)[0])

# %%
patch_out_max = np.argmax(patch_out, axis=-1)

# %%
out = pe.reconstruct(patch_out_max.reshape(pe.patch_array_shape))

# %%
fig, axs = plt.subplots(1, 3, sharey=True, figsize=(19, 8))

data=axs[0].imshow(test_image.T, clim=(-1000,1000))
axs[0].set_title('Data')
axs[0].axis('tight')
fig.colorbar(data, ax=axs[0],  label='amplitude')

plot_label(test_label.T, fig, axs[1], num_classes, labels=CLASS_NAMES, cmap='tab10')
axs[1].set_title('Label')
axs[1].axis('tight')

plot_label(out, fig, axs[2], num_classes, labels=CLASS_NAMES, cmap='tab10')
axs[2].set_title('Output')
axs[2].axis('tight')
           
plt.show()
